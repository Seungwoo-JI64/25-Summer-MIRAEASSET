# %% [markdown]
# # AI 애널리스트 분석 파이프라인
#
# 각 에이전트를 순차적으로 실행하여 최종 투자 브리핑을 생성하는 파이프라인입니다.
# 각 셀을 순서대로 실행하세요 (Shift + Enter).

# %%
import os
import sys
from dotenv import load_dotenv
from pprint import pprint

# --- 경로 문제 해결 --- 
# 현재 노트북 파일의 상위 폴더(프로젝트 루트)를 파이썬 경로에 추가합니다.
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
# ---------------------

# .env 파일의 환경 변수를 가장 먼저 로드합니다.
load_dotenv()

# analysis_model 패키지 내 모듈들을 import 합니다.
from analysis_model.state import AnalysisState
from analysis_model.agents.data_prep_agent import run_data_prep
from analysis_model.agents.news_analyst_agent import run_news_analyst
from analysis_model.agents.domestic_news_analyst_agent import run_domestic_news_analyst
from analysis_model.agents.market_correlation_agent import run_market_correlation
from analysis_model.agents.report_synthesizer_agent import run_report_synthesizer

print("✅ 모든 모듈이 성공적으로 import 되었습니다.")
# Out:
# Supabase에서 기업 및 뉴스 데이터 로딩 및 전처리를 시작합니다...
# 데이터 로딩 및 전처리 완료.
# Supabase에서 기업 및 뉴스 데이터 로딩 및 전처리를 시작합니다...
# 데이터 로딩 및 전처리 완료.
# ✅ 모든 모듈이 성공적으로 import 되었습니다.

# %% [markdown]
# ## 1. 분석 대상 기업 설정

# %%
# 분석을 시작할 기업의 티커를 설정합니다.
initial_state: AnalysisState = {
    "ticker": "000660.KS",  # SK하이닉스 예시
    "company_name": None,
    "company_description": None,
    "financial_health": None,
    "selected_news": None,
    "selected_domestic_news": None,
    "market_analysis_result": None,
    "final_report": None,
}

print(f"🚀 '{initial_state['ticker']}' 기업에 대한 분석을 시작합니다.")
# Out:
# 🚀 '000660.KS' 기업에 대한 분석을 시작합니다.

# %% [markdown]
# ## 2. 전체 파이프라인 실행
#
# 아래 셀을 실행하면 모든 에이전트가 순차적으로 작동합니다.

# %%
# --- 파이프라인 순차 실행 ---
current_state = initial_state.copy()

print("--- [1/5] 데이터 준비 에이전트 실행 중 ---")
current_state.update(run_data_prep(current_state))
print("✅ 완료\n")

print("--- [2/5] 해외 뉴스 분석 에이전트 실행 중 ---")
current_state.update(run_news_analyst(current_state))
print("✅ 완료\n")

print("--- [3/5] 국내 뉴스 분석 에이전트 실행 중 ---")
current_state.update(run_domestic_news_analyst(current_state))
print("✅ 완료\n")

print("--- [4/5] 시장 데이터 분석 에이전트 실행 중 ---")
current_state.update(run_market_correlation(current_state))
print("✅ 완료\n")

print("--- [5/5] 최종 투자 브리핑 생성 에이전트 실행 중 ---")
current_state.update(run_report_synthesizer(current_state))
print("✅ 완료")
# Out:
# --- [1/5] 데이터 준비 에이전트 실행 중 ---
# ✅ 완료
#
# --- [2/5] 해외 뉴스 분석 에이전트 실행 중 ---
#
# ---  뉴스 분석 에이전트 실행 ---
# 🔍 [News Analyst] Supabase 벡터 검색으로 'SK Hynix' 관련 뉴스 15개를 검색합니다.
# [News Analyst] Gemini AI를 호출하여 15개 뉴스 중 핵심 뉴스 3개를 선별합니다.
#
# ========================================
# >>> Gemini API Raw Response (for Debugging) <<<
# ```json
# {"selected_news": [{"index": 1, "related_tickers": ["^NDX", "USDKRW=X"]}, {"index": 6, "related_tickers": ["NVDA", "AMD"]}, {"index": 12, "related_tickers": ["AMAT", "MU"]}]}
# ```
# ========================================
#
# Gemini가 성공적으로 파싱한 뉴스 정보: [{'index': 1, 'related_tickers': ['^NDX', 'USDKRW=X']}, {'index': 6, 'related_tickers': ['NVDA', 'AMD']}, {'index': 12, 'related_tickers': ['AMAT', 'MU']}]
#   - 뉴스 선별: "Whitmer says 'massive economic uncertainty' is to blame on semiconductor project failure in Michigan" (연관 Ticker: ['^NDX', 'USDKRW=X'])
#   - 뉴스 선별: "Nvidia’s Huang Wins China Reprieve in Trade War Reversal" (연관 Ticker: ['NVDA', 'AMD'])
#   - 뉴스 선별: "ASML sees share price drop as Trump’s tariffs darken outlook" (연관 Ticker: ['AMAT', 'MU'])
# ✅ 완료
#
# --- [3/5] 국내 뉴스 분석 에이전트 실행 중 ---
#
# ---  뉴스 분석 에이전트 실행 ---
# 🔍 [News Analyst] Supabase 벡터 검색으로 'SK Hynix' 관련 뉴스 15개를 검색합니다.
# [News Analyst] Gemini AI를 호출하여 15개 뉴스 중 핵심 뉴스 3개를 선별합니다.
#
# ========================================
# >>> Gemini API Raw Response (for Debugging) <<<
# ```json
# {
#   "selected_domestic_news": [
#     {
#       "index": 1,
#       "related_tickers": ["NVDA", "^KS11"]
#     },
#     {
#       "index": 2,
#       "related_tickers": ["NVDA", "^KS11"]
#     },
#     {
#       "index": 12,
#       "related_tickers": ["^KS11"]
#     }
#   ]
# }
# ```
# ========================================
#
# Gemini가 성공적으로 파싱한 뉴스 정보: [{'index': 1, 'related_tickers': ['NVDA', '^KS11']}, {'index': 2, 'related_tickers': ['NVDA', '^KS11']}, {'index': 12, 'related_tickers': ['^KS11']}]
#   - 뉴스 선별: "SK하이닉스, 30만원에 마감…2012년 SK그룹 편입 후 최고가" (연관 Ticker: ['NVDA', '^KS11'])
#   - 뉴스 선별: "[특징주] 14년래 최고가 찍은 SK하이닉스, 장초반 하락세" (연관 Ticker: ['NVDA', '^KS11'])
#   - 뉴스 선별: "골드만삭스, SK하이닉스 투자의견 '중립'으로 하향조정" (연관 Ticker: ['^KS11'])
# ✅ 완료
#
# --- [4/5] 시장 데이터 분석 에이전트 실행 중 ---
#
# --- 📈 시장 상관관계 및 뉴스 영향 분석 에이전트 실행 ---
# 분석 대상 전체 고유 지표: {'USDKRW=X', 'AMAT', 'NVDA', 'MU', '^NDX', '^KS11', 'AMD'}
#   - Supabase에서 'USDKRW=X' 데이터 조회 (기간: 2025-07-07 ~ 2025-07-24)
#   - Supabase에서 'AMAT' 데이터 조회 (기간: 2025-07-07 ~ 2025-07-24)
#   - Supabase에서 'NVDA' 데이터 조회 (기간: 2025-07-07 ~ 2025-07-24)
#   - Supabase에서 '000660.KS' 데이터 조회 (기간: 2025-07-07 ~ 2025-07-24)
#   - Supabase에서 'MU' 데이터 조회 (기간: 2025-07-07 ~ 2025-07-24)
#   - Supabase에서 '^NDX' 데이터 조회 (기간: 2025-07-07 ~ 2025-07-24)
#   - Supabase에서 '^KS11' 데이터 조회 (기간: 2025-07-07 ~ 2025-07-24)
#   - Supabase에서 'AMD' 데이터 조회 (기간: 2025-07-07 ~ 2025-07-24)
# ✅ 완료
#
# --- [5/5] 최종 투자 브리핑 생성 에이전트 실행 중 ---
#
# --- ✍️ 최종 투자 브리핑 생성 에이전트 (Multi-LLM) 실행 ---
#   - [1단계] '분석가 LLM' 호출: 개별 주체 심층 분석 요청
#   - [2단계] '작성가 LLM' 호출: 최종 보고서 작성 요청
# ✅ [Report Synthesizer] Multi-LLM 기반 최종 브리핑 생성을 완료했습니다.
# ✅ 완료

# %% [markdown]
# ## 3. 최종 결과 확인

# %%
# --- 최종 결과 확인 ---
print("=" * 20 + " 최종 생성된 투자 브리핑 (JSON) " + "=" * 20 + "\n")

# final_report = current_state.get("selected_news")
# final_report = current_state.get("selected_domestic_news")
# final_report = current_state.get("market_analysis_result")
final_report = current_state.get("final_report")
if final_report:
    # pprint를 사용하여 최종 결과를 있는 그대로 출력합니다.
    pprint(final_report)
else:
    print("최종 보고서가 생성되지 않았습니다.")

print("\n" + "=" * 60)
# Out:
# ==================== 최종 생성된 투자 브리핑 (JSON) ====================
#
# {'briefing_summary': 'SK 하이닉스는 달러/원 환율 상승에 따른 긍정적인 영향이 예상되며, NVIDIA와의 장기적인 양의 '
#                      '상관관계로 인해 중장기적인 매출 성장이 기대됩니다. 그러나 Applied Materials로부터의 '
#                      '공급망 불확실성 및 Micron Technology와의 경쟁 심화는 단기적으로 주의가 필요합니다.',
#  'news_analysis': {'entity_analysis': {'AMD(AMD)': {'내용': 'AMD의 주가 상승은 컴퓨터 및 '
#                                                           '서버 시장의 성장세를 반영하며, '
#                                                           '이는 SK하이닉스의 D 램 및 '
#                                                           '에스디램(SDRAM) 수요 증가로 '
#                                                           '이어질 수 있습니다. 특히, 게임 '
#                                                           '콘솔과 데이터 센터 분야에서의 수요 '
#                                                           '증가는 SK하이닉스의 매출 성장을 '
#                                                           '견인할 수 있는 중요한 요인이 '
#                                                           '됩니다.',
#                                                     '주가_반응': 'AMD의 주가 상승은 '
#                                                              'SK하이닉스의 주가에 긍정적인 '
#                                                              '영향을 미치며, 특히 게임 '
#                                                              '콘솔과 데이터 센터 분야에서의 '
#                                                              '수요 증가를 통해 중장기적으로 '
#                                                              '회사의 매출 성장을 촉진할 '
#                                                              '것입니다.'},
#                                        'Applied Materials(AMAT)': {'내용': 'Applied '
#                                                                          'Materials는 '
#                                                                          '반도체 '
#                                                                          '장비 '
#                                                                          '공급업체로, '
#                                                                          'SK하이닉스의 '
#                                                                          '생산 '
#                                                                          '공정에 '
#                                                                          '필수적인 '
#                                                                          '장비를 '
#                                                                          '제공합니다. '
#                                                                          '최근 '
#                                                                          '13일간 '
#                                                                          '약 '
#                                                                          '0.29% '
#                                                                          '하락한 '
#                                                                          '주가는 '
#                                                                          '공급망 '
#                                                                          '문제와 '
#                                                                          '관련된 '
#                                                                          '불확실성을 '
#                                                                          '반영합니다. '
#                                                                          '이러한 '
#                                                                          '상황은 '
#                                                                          'SK하이닉스의 '
#                                                                          '생산 '
#                                                                          '비용 '
#                                                                          '증가로 '
#                                                                          '이어질 '
#                                                                          '수 '
#                                                                          '있으며, '
#                                                                          '단기적으로는 '
#                                                                          '이익률 '
#                                                                          '감소의 '
#                                                                          '원인이 '
#                                                                          '될 수 '
#                                                                          '있습니다.',
#                                                                    '주가_반응': 'Applied '
#                                                                             'Materials의 '
#                                                                             '주가 '
#                                                                             '하락은 '
#                                                                             'SK하이닉스의 '
#                                                                             '장비 '
#                                                                             '조달 '
#                                                                             '비용을 '
#                                                                             '증가시켜, '
#                                                                             '단기적으로 '
#                                                                             '이익률에 '
#                                                                             '부정적인 '
#                                                                             '영향을 '
#                                                                             '미칠 '
#                                                                             '수 '
#                                                                             '있습니다.'},
#                                        'Micron Technology(MU)': {'내용': 'Micron '
#                                                                        'Technology는 '
#                                                                        '경쟁사 대비 '
#                                                                        '상대적으로 '
#                                                                        '낮은 주가 '
#                                                                        '수준을 '
#                                                                        '유지하고 '
#                                                                        '있으나, '
#                                                                        '최근 '
#                                                                        '13일간 약 '
#                                                                        '5.00% '
#                                                                        '하락한 '
#                                                                        '주가는 '
#                                                                        '메모리 '
#                                                                        '시장에서의 '
#                                                                        '경쟁 심화와 '
#                                                                        '수요 부진을 '
#                                                                        '시사합니다. '
#                                                                        '이는 '
#                                                                        'SK하이닉스의 '
#                                                                        '경쟁 환경에 '
#                                                                        '도전 과제를 '
#                                                                        '제시하지만, '
#                                                                        '동시에 '
#                                                                        '저평가 '
#                                                                        '매력도 '
#                                                                        '부각시킬 수 '
#                                                                        '있습니다.',
#                                                                  '주가_반응': 'Micron '
#                                                                           'Technology의 '
#                                                                           '주가 '
#                                                                           '하락은 '
#                                                                           'SK하이닉스에 '
#                                                                           '대해 '
#                                                                           '메모리 '
#                                                                           '시장의 '
#                                                                           '경쟁 '
#                                                                           '강도가 '
#                                                                           '높아지고 '
#                                                                           '있음을 '
#                                                                           '나타내며, '
#                                                                           'SK하이닉스는 '
#                                                                           '이에 '
#                                                                           '대응하기 '
#                                                                           '위한 '
#                                                                           '전략적 '
#                                                                           '조치를 '
#                                                                           '고려해야 '
#                                                                           '할 '
#                                                                           '필요가 '
#                                                                           '있습니다.'},
#                                        'NVIDIA(NVDA)': {'내용': 'NVIDIA는 그래픽 처리 '
#                                                               '장치(GPU) 시장의 선두 '
#                                                               '업체로서, 인공지능 및 '
#                                                               '데이터 센터 분야에서 강력한 '
#                                                               '수요를 받고 있습니다. 최근 '
#                                                               '13일간 약 8.89% '
#                                                               '상승한 주가는 이러한 성장 '
#                                                               '잠재력을 반영합니다. 이는 '
#                                                               'SK하이닉스의 D 램 및 '
#                                                               '낸드 플래시 수요 증가로 '
#                                                               '이어질 수 있어, '
#                                                               '중장기적으로 긍정적인 영향을 '
#                                                               '줄 것으로 예상됩니다.',
#                                                         '주가_반응': 'NVIDIA의 주가 '
#                                                                  '상승은 SK하이닉스의 '
#                                                                  '주요 제품인 D 램 및 '
#                                                                  '낸드 플래시에 대한 '
#                                                                  '수요 증가를 의미하며, '
#                                                                  '이는 중장기적으로 '
#                                                                  'SK하이닉스의 매출 '
#                                                                  '성장을 촉진할 '
#                                                                  '것입니다.'},
#                                        '나스닥 100 지수(^NDX)': {'내용': '나스닥 100 지수의 '
#                                                                   '상승은 기술주 전반에 '
#                                                                   '긍정적인 분위기를 '
#                                                                   '조성하며, 이는 '
#                                                                   'SK하이닉스와 같은 '
#                                                                   '기술 중심의 반도체 '
#                                                                   '회사에 호재로 작용할 '
#                                                                   '수 있습니다. 특히, '
#                                                                   '인공지능 및 클라우드 '
#                                                                   '컴퓨팅 분야의 수요 '
#                                                                   '증가는 SK하이닉스의 '
#                                                                   'D 램 및 '
#                                                                   '에스디램(SDRAM) '
#                                                                   '수요를 높일 가능성이 '
#                                                                   '큽니다.',
#                                                             '주가_반응': '나스닥 100 '
#                                                                      '지수의 상승은 '
#                                                                      'SK하이닉스의 '
#                                                                      '주가에 긍정적인 '
#                                                                      '영향을 미치며, '
#                                                                      '특히 인공지능 '
#                                                                      '및 데이터 센터 '
#                                                                      '분야에서의 수요 '
#                                                                      '증가를 통해 '
#                                                                      '중장기적으로 '
#                                                                      '회사의 성장 '
#                                                                      '가능성을 '
#                                                                      '높입니다.'},
#                                        '달러/원 환율(USDKRW=X)': {'내용': '환율은 '
#                                                                    'SK하이닉스의 '
#                                                                    '수익성과 직결되는 '
#                                                                    '중요한 요소입니다. '
#                                                                    '최근 14일간 약 '
#                                                                    '2.10% 상승한 '
#                                                                    '환율은 회사의 수출 '
#                                                                    '경쟁력을 '
#                                                                    '강화시키고, 매출 '
#                                                                    '증가를 기대하게 '
#                                                                    '만듭니다. 이는 '
#                                                                    'SK하이닉스가 해외 '
#                                                                    '시장에서 더 높은 '
#                                                                    '가격으로 제품을 '
#                                                                    '판매할 수 있게 '
#                                                                    '하여 순이익률을 '
#                                                                    '개선시킬 가능성이 '
#                                                                    '있습니다.',
#                                                              '주가_반응': '최근 환율 '
#                                                                       '상승은 '
#                                                                       'SK하이닉스의 '
#                                                                       '주가에 '
#                                                                       '긍정적인 '
#                                                                       '영향을 '
#                                                                       '미쳤습니다. '
#                                                                       '특히, 7월 '
#                                                                       '7일부터 7월 '
#                                                                       '18일까지의 '
#                                                                       '기간에 환율 '
#                                                                       '상승과 함께 '
#                                                                       '주가가 '
#                                                                       '지속적으로 '
#                                                                       '상승하는 '
#                                                                       '모습을 '
#                                                                       '보였습니다.'},
#                                        '코스피 지수(^KS11)': {'내용': '코스피 지수의 상승은 한국 '
#                                                                '주식 시장에 대한 신뢰도를 '
#                                                                '반영하며, 이는 '
#                                                                'SK하이닉스의 전반적인 '
#                                                                '투자 환경을 긍정적으로 '
#                                                                '만듭니다. 또한, 국내 '
#                                                                '반도체 산업에 대한 '
#                                                                '지속적인 지원과 투자는 '
#                                                                'SK하이닉스의 경쟁력 '
#                                                                '강화에 기여할 것입니다.',
#                                                          '주가_반응': '코스피 지수의 상승은 '
#                                                                   'SK하이닉스의 주가에 '
#                                                                   '긍정적인 영향을 '
#                                                                   '미치며, 회사의 재무 '
#                                                                   '안정성과 미래 성장 '
#                                                                   '가능성에 대한 신뢰를 '
#                                                                   '높입니다.'}}},
#  'report_title': '[오늘의 투자 브리핑] SK Hynix 기업 관련 주요 동향 및 전략',
#  'strategy_suggestion': 'SK 하이닉스에 대한 투자 전략으로는 현재의 달러/원 환율 상승 추세를 활용하여 수출 경쟁력 '
#                         '강화를 통한 매출 증가 기회를 포착하는 것이 중요합니다. 또한, NVIDIA와의 긴밀한 관계를 '
#                         '바탕으로 한 기술 혁신 및 수요 증가에 대비해 중장기적인 성장 포텐셜을 탐색해야 합니다. 다만, '
#                         'Applied Materials와 Micron Technology의 공급망 이슈와 경쟁 상황을 '
#                         '주시하면서 리스크 관리에도 유의해야 합니다.'}
#
# ============================================================
